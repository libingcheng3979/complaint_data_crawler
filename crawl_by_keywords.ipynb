# %% [markdown]
# # 字段解析

# %%
import requests
import json
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def get_search_results(keywords, pageNum, pageSize=100):
    """
    获取搜索结果
    :param keywords: 搜索关键词
    :param pageNum: 页码
    :param pageSize: 每页显示条数
    :return: 响应json数据
    """
    url = "https://api1.liuyan.cjn.cn/messageboard/api/essearch/querySearchMapByPage"
    headers = {
        'Accept': 'application/json',
        'Content-Type': 'application/x-www-form-urlencoded',
        'Origin': 'https://liuyan.cjn.cn',
        'Referer': 'https://liuyan.cjn.cn/',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    data = {
        'keywords': keywords,
        'pageSize': pageSize,
        'pageNum': pageNum
    }
    
    response = requests.post(url, headers=headers, data=data, verify=False)
    response.raise_for_status()
    return response.json()

if __name__ == "__main__":
    keywords = "交通噪音"
    pageNum = 1
    results = get_search_results(keywords, pageNum)
    print(json.dumps(results, indent=4, ensure_ascii=False))
# Out:
# {
#     "msg": "操作成功",
#     "code": 0,
#     "data": {
#         "total": 144,
#         "rows": [
#             {
#                 "highlight": {
#                     "content": "出租车和网约车是城市<span style='color:red'>交通</span><span style='color:red'>噪音</span>的一大来源，不管是红绿灯人行道还是小区内道路，这类车辆是最爱按喇叭催促的，建议参考公交车，屏蔽或拆除出租车和网约车的喇叭。请直接留言，无需电话回访。"
#                 },
#                 "source": {
#                     "fid": "101",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "17",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1746358440,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2025]02010126",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 1,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "517228230933807104",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "smrxGetReplyed": 0,
#                     "subject": "建议屏蔽或拆除出租车和网约车的喇叭",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "15",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1236279663860068352",
#                     "queryCode": 3506033,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2025]02010126",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "f*****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1746502041,
#                     "fids": null,
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "是",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "出租车和网约车是城市交通噪音的一大来源，不管是红绿灯人行道还是小区内道路，这类车辆是最爱按喇叭催促的，建议参考公交车，屏蔽或拆除出租车和网约车的喇叭。请直接留言，无需电话回访。",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": null,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "武汉市人民政府/武汉市城市管理委员会：​\n<br>作为黄家湖大道军运村地铁站段周边小区居民，我们长期受该路段<span style='color:red'>交通</span><span style='color:red'>噪音</span>困扰，特此反馈问题并恳请协调解决。"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "635836920174825472",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1743259277,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2025]01394230",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 0,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "1223276600210681856",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "smrxGetReplyed": 0,
#                     "subject": "关于黄家湖大道军运村地铁站段路面噪音问题反馈",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "1",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1223280830792937472",
#                     "queryCode": 3462417,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2025]01394230",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "手机用户-174325826689****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1743259277,
#                     "fids": null,
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "否",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "武汉市人民政府/武汉市城市管理委员会：​\n<br>作为黄家湖大道军运村地铁站段周边小区居民，我们长期受该路段交通噪音困扰，特此反馈问题并恳请协调解决。\n<br>\n<br>问题描述：​\n<br>黄家湖大道军运村地铁站段因路面宽阔、车道设计合理，车辆通行速度普遍较高，尤其夜间大货车频繁通行。根据实地观察，部分车辆时速超过80公里/小时，且重型货车在加速、制动产生持续性低频噪音，严重干扰周边小区（融创城、保利军运村、金茂华发国际社区等）居民夜间休息。根据《中华人民共和国噪声污染防治法》及《武汉市环境噪声污染防治条例》，该路段噪音已明显超出居住区夜间限值标准。\n<br>\n<br>具体诉求：​\n<br>​1、增设测速与减速设施：建议安装区间测速设备，并在临近小区路段设置震荡减速带或智慧警示灯，强制降低车速；\n<br>2、​优化货车通行管理：参考《武汉市货车交通管理措施》，对该路段重型货车实施夜间限行（如22:00-6:00禁止通行），或划定绕行路线；\n<br>​3、加装隔音屏障：在道路两侧或中央绿化带增设全封闭/半封闭式隔音屏；\n<br>​4、提升路面降噪性能：改用多孔沥青等低噪材料铺设路面，减少轮胎与地面摩擦声。\n<br>\n<br>法律依据与参考案例：​\n<br>《中华人民共和国噪声污染防治法》第六章第四十六条明确要求交通干线两侧应设置声屏障等降噪设施；",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": "1",
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": 3,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "自二环线通车以来，<span style='color:red'>交通</span><span style='color:red'>噪音</span>问题一直困扰着汉阳名流公馆NK4区附近居民近十年未解决。"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "17",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1736140184,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2025]00086387",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 1,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "1169685741913853952",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "smrxGetReplyed": 0,
#                     "subject": "二环线马鹦路段车流噪声问题",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "19",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1193421188792791040",
#                     "queryCode": 3369434,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2025]00086387",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "手机用户-173048121058****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1736141169,
#                     "fids": "705571437862064128",
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "是",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "二环线马鹦路段车流噪声问题。 自二环线通车以来，交通噪音问题一直困扰着汉阳名流公馆NK4区附近居民近十年未解决。尽管曾在市长热线反映过这一问题，并且环保局也于今年11月底进行了噪音监测，确认噪音水平超标，但至今仍未见到任何实质性的改善措施。 长期的噪音污染不仅严重影响了周边居民睡眠质量和身心健康，还可能引发心血管疾病等健康问题。为此，恳请相关部门能够重视这一问题，并采取以下措施： 1. 持续监测并公开数据：请环保部门定期对二环线附近的噪音水平进行监测，并将监测结果向公众公开，以便居民了解噪音污染的实际情况。 2. 安装隔音设施：在二环线靠近居民区的路段安装隔音屏或隔音墙，周边增加绿化等各种措施，以有效降低噪音对居民的影响。 3. 优化交通管理：通过调整交通流量和优化交通信号灯设置，减少车辆拥堵和频繁启停带来的噪音。 4. 加强政策落实与监督：确保《中华人民共和国环境噪声污染防治法》及相关政策得到有效落实，并加强对噪音污染防治工作的监督。 希望相关部门能够高度重视这一问题，采取切实有效的措施，还我们一个宁静的生活环境。感谢您的关注和支持！ ",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": null,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "依职权认定，旭辉千山凌云段存在违反声环境质量标准（GB3096-2008）强制性国标，涉及群体众多长期以来，光谷大道高架的<span style='color:red'>交通</span><span style='color:red'>噪音</span>对周边居民的生活和健康造成了严重影响，大家对此问题高度关注并迫切希望得到解决"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "635836920174825472",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1732151633,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2024]06312337",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 1,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "1014009305030123520",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 1,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "smrxGetReplyed": 0,
#                     "subject": "小区旁高架噪音严重超标",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "1",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1176691994022674432",
#                     "queryCode": 3309197,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2024]06312337",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "手机用户-169336505593****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1732151633,
#                     "fids": null,
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "是",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "尊敬的政府领导：\n<br>您好！\n<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;关于光谷大道高架旭辉千山凌云段全封闭隔音棚的问题，我们在之前已进行投诉，并接到回复称问题已经上报。然而，每次的回复都只是表示问题已经上报，依然没有明确的时间表或具体解决方案。\n<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;中央环保督察组已于2024年5月12号，于湖北省生态环境厅官网对外公示第12批，受理编号：X3HB202405190003,序号：23。依职权认定，旭辉千山凌云段存在违反声环境质量标准（GB3096-2008）强制性国标，涉及群体众多长期以来，光谷大道高架的交通噪音对周边居民的生活和健康造成了严重影响，大家对此问题高度关注并迫切希望得到解决。噪音治理事关民生福祉，我们恳请相关部门能够具体落实措施，明确推进时间表，而不是一再重复上报的说法。希望能够尽快给出切实可行的解决方案，切实回应居民的诉求。\n<br>感谢您对该问题的关注与处理！",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": "1",
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": null,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "subject": "后湖南路与怡康路，违停堵塞<span style='color:red'>交通</span>，<span style='color:red'>噪音</span>扰民"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "635836920174825472",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1729324377,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2024]05727825",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 1,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "175345",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": "[{\"endtime\":1730101986,\"endtime_txt\":\"2024-10-28 15:53:06\",\"forumUnid\":\"705571437862064128\",\"handlestate\":0,\"handletime\":1729324386,\"handletime_txt\":\"2024-10-19 15:53:06\",\"organization\":\"留言板\",\"over\":true,\"params\":{},\"plate\":\"各区(功能区)\",\"plateId\":\"1\"}]",
#                     "smrxGetReplyed": 0,
#                     "subject": "后湖南路与怡康路，违停堵塞交通，噪音扰民",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "15",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1164833625316470784",
#                     "queryCode": 3255844,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2024]05727825",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "微信用户-155905470****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1729324377,
#                     "fids": null,
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "是",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "后湖南路与怡康路交接口，每个周六周日，中午下午，3点到五点，长年马路两边违停，怡康路两边并没有停车位规划，违停导致两车道变一车道，甚至半车道，堵塞交通，导致车辆疯狂按喇叭，噪音扰民。而且都是附近教育机构接送小孩的车辆，建议交通部门，加大这类特定时间段的违停整治，建议教育部门严查",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 1,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": null,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "subject": "光谷app十字路口摆摊阻挡<span style='color:red'>交通</span>，<span style='color:red'>噪音</span>扰民"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "parentKindId": null,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "departUnid": null,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 0,
#                     "ansCheckState": 0,
#                     "answerNum": null,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "kindIds": null,
#                     "anonymousCode": null,
#                     "caseNum": null,
#                     "searchHandtimeEndTxt": null,
#                     "searchStartTime": null,
#                     "answerEndTime": null,
#                     "lybhvalue": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "cjwSynced2": null,
#                     "feedbackState": null,
#                     "timelyTime": null,
#                     "hiddenInfo": null,
#                     "queryKindIds": null,
#                     "lastFeedbackTime": null,
#                     "leaderName": null,
#                     "urgeContent": null,
#                     "typeId": "635836920174825472",
#                     "fdidNum": null,
#                     "queryFids": null,
#                     "searchHandtimeStart": null,
#                     "extraInfo": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1724074271,
#                     "committeeUnid": null,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": null,
#                     "isShowSecondHand": null,
#                     "phonenumber": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "answerAttachment": null,
#                     "answerMan": null,
#                     "smrxDataId": "[2024]04284669",
#                     "complainTransferNum": null,
#                     "queryFeedbackCreateTime": null,
#                     "queryCodes": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "creatTime": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "enterpriseName": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "readState": null,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "answerStartTimeTxt": null,
#                     "answerKeywords": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "answerStartTime": null,
#                     "feedbackEndTime": null,
#                     "sfnm": 1,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 0,
#                     "userId": "691201837144453120",
#                     "traceState": 0,
#                     "answerEndTimeTxt": null,
#                     "queryFeedbackEndTime": null,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "committeeName": null,
#                     "domainId_txt": null,
#                     "queryCodeList": [],
#                     "endTime": null,
#                     "searchHandtimeEnd": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "smrxGetReplyed": 0,
#                     "subject": "光谷app十字路口摆摊阻挡交通，噪音扰民",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "15",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "1142813085029396480",
#                     "queryCode": 3169770,
#                     "forbidAttachementsList": null,
#                     "queryFeedbackStartTime": null,
#                     "availableTime": 0,
#                     "verifycode": null,
#                     "timelyAnswered": 0,
#                     "limit": null,
#                     "acceptNum": null,
#                     "commentsNum": 0,
#                     "markState": 0,
#                     "lybh": "[2024]04284669",
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "手机用户-161640175529****",
#                     "queryDomainIds": null,
#                     "leaderPhone": null,
#                     "domainId": "450",
#                     "topicId": null,
#                     "postCode": null,
#                     "lastupdate": 1724074337,
#                     "fids": null,
#                     "keywordSet": null,
#                     "cjwSynced": null,
#                     "userCity": null,
#                     "gids": null,
#                     "operat": null,
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "sfnmStr": "是",
#                     "answersList": null,
#                     "searchHandtimeStartTxt": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": null,
#                     "orderByColumn": null,
#                     "content": "光谷app十字路口小商贩摆摊都摆到路中间来了，烧烤，播放音乐持续时间已快一年，请问这个有那个部门能管一管",
#                     "departUnid_txt": null,
#                     "isComplain": null,
#                     "deleteInfo": null,
#                     "attachment": 1,
#                     "updateBy": null,
#                     "kindIds_txt": null,
#                     "urgeNum": null,
#                     "company": null,
#                     "feedbackStartTime": null,
#                     "feedbackList": null,
#                     "postStr": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "sfba": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "submittedMessageboard": null,
#                     "isOpenComment": 1,
#                     "userCityArea": null,
#                     "useSatisfaction": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "viewcount": null,
#                     "extraInfoStr": null,
#                     "hasSecAnswer": false,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "汽车喇叭声是<span style='color:red'>交通</span><span style='color:red'>噪音</span>污染的主要来源，大车的鸣笛声更会超过80分贝。根据《中华人民共和国环境噪声污染防治法》，超过国家规定的环境噪声排放标准。望相关部门依据法律规定设置合理的货车通行规划路线和禁鸣区。"
#                 },
#                 "source": {
#                     "fid": "705571437862064128",
# ...
#                     "content": "一直未解决，晚上22-凌晨都有车高速轰鸣且鸣笛，居民区集中区域扰民不管也不接受建议立交通警示牌限速禁鸣笛！！！！",
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "urgeNum": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "妨碍<span style='color:red'>交通</span>，<span style='color:red'>噪音</span>扰民，请将这些人引导到小区外锻炼。\n小区已经反应多次这个问题，请政府协助我们能够享受基本的安宁环境，"
#                 },
#                 "source": {
#                     "fid": "15",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 2,
#                     "ansCheckState": 1,
#                     "answerNum": 1,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "anonymousCode": "203898",
#                     "caseNum": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "feedbackState": null,
#                     "hiddenInfo": null,
#                     "lastFeedbackTime": null,
#                     "urgeContent": null,
#                     "typeId": "5",
#                     "fdidNum": 1,
#                     "queryFids": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1563579552,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": 1564475467,
#                     "isShowSecondHand": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "complainTransferNum": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 9,
#                     "userId": "175449",
#                     "traceState": 3,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "domainId_txt": null,
#                     "endTime": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "subject": "美联奥林匹克花园2期24栋25栋之间占道扰民",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "15",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "421486",
#                     "queryCode": 421486,
#                     "availableTime": 0,
#                     "timelyAnswered": 1,
#                     "limit": null,
#                     "commentsNum": 0,
#                     "markState": 1,
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "微信用户-155909551****",
#                     "queryDomainIds": null,
#                     "domainId": "26",
#                     "topicId": "0",
#                     "postCode": null,
#                     "lastupdate": 1564789966,
#                     "fids": "15",
#                     "keywordSet": null,
#                     "gids": "15,",
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "answersList": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": "350202",
#                     "content": "东西湖二期24栋25栋之间有人占据园区道路，踢毽子，打网球。妨碍交通，噪音扰民，请将这些人引导到小区外锻炼。\n小区已经反应多次这个问题，请政府协助我们能够享受基本的安宁环境，",
#                     "deleteInfo": null,
#                     "attachment": 1,
#                     "updateBy": null,
#                     "urgeNum": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "content": "我是发展大道27号A栋2单元1503室住户，自从五年前二环线（常码头附近）开通后，由于二环线上没有安装消除噪音的隔音设置，产生的<span style='color:red'>交通</span><span style='color:red'>噪音</span>非常大，住户无任白天夜里都不敢开窗户，晚上无法安睡。"
#                 },
#                 "source": {
#                     "fid": "127",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 2,
#                     "ansCheckState": 1,
#                     "answerNum": 1,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "anonymousCode": "360631",
#                     "caseNum": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": "{\"reason\":\"原建设单位地产集团，转市地产集团办理。\",\"organization\":\"武汉城投集团\",\"url\":\"留言查询码：415539\"}",
#                     "feedbackState": null,
#                     "hiddenInfo": null,
#                     "lastFeedbackTime": null,
#                     "urgeContent": null,
#                     "typeId": "6",
#                     "fdidNum": 1,
#                     "queryFids": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1563088766,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": 1564395083,
#                     "isShowSecondHand": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "complainTransferNum": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 3,
#                     "userId": "196645",
#                     "traceState": 1,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "domainId_txt": null,
#                     "endTime": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "subject": "请求安装隔音设备",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "14",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "415539",
#                     "queryCode": 415539,
#                     "availableTime": 0,
#                     "timelyAnswered": 1,
#                     "limit": null,
#                     "commentsNum": 0,
#                     "markState": 1,
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "手机用户-156308734****",
#                     "queryDomainIds": null,
#                     "domainId": "287",
#                     "topicId": "0",
#                     "postCode": null,
#                     "lastupdate": 1564395083,
#                     "fids": "127",
#                     "keywordSet": null,
#                     "gids": "126,",
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "answersList": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": "349309",
#                     "content": "我是发展大道27号A栋2单元1503室住户，自从五年前二环线（常码头附近）开通后，由于二环线上没有安装消除噪音的隔音设置，产生的交通噪音非常大，住户无任白天夜里都不敢开窗户，晚上无法安睡。",
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "urgeNum": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             },
#             {
#                 "highlight": {
#                     "subject": "渣土运输车<span style='color:red'>交通</span><span style='color:red'>噪音</span>扰民"
#                 },
#                 "source": {
#                     "fid": "8",
#                     "lastcheck": null,
#                     "handleTogetherState": null,
#                     "fdFailCount": 0,
#                     "answers": null,
#                     "fidsNum": 1,
#                     "isFocusOn": null,
#                     "answerStateRange": null,
#                     "score": 0,
#                     "handleState": 2,
#                     "ansCheckState": 1,
#                     "answerNum": 1,
#                     "reportState": 0,
#                     "typeId_txt": null,
#                     "anonymousCode": "425718",
#                     "caseNum": null,
#                     "searchEndTime": null,
#                     "params": {},
#                     "checkReason": null,
#                     "feedbackState": null,
#                     "hiddenInfo": null,
#                     "lastFeedbackTime": null,
#                     "urgeContent": null,
#                     "typeId": "6",
#                     "fdidNum": 1,
#                     "queryFids": null,
#                     "handleTogetherFid": null,
#                     "fupStr": null,
#                     "dateline": 1562856316,
#                     "processState": 0,
#                     "courtCode": null,
#                     "log": null,
#                     "lastAnswerTime": 1563348423,
#                     "isShowSecondHand": null,
#                     "recommend": 0,
#                     "handletogetherLastAnswerTime": "",
#                     "complainTransferNum": null,
#                     "queryMessageCreateTime": null,
#                     "userHead": null,
#                     "secondState": null,
#                     "topicId_txt": null,
#                     "subjectSet": null,
#                     "topicMap": null,
#                     "leaderAnswer": 0,
#                     "dateline_txt": null,
#                     "customUser": null,
#                     "streetCode": null,
#                     "domainExtend": null,
#                     "endTime_txt": null,
#                     "updateTime": null,
#                     "viewsNum": "0",
#                     "satisfaction": 3,
#                     "userId": "175359",
#                     "traceState": 1,
#                     "overt": 1,
#                     "complainType": null,
#                     "fidStr": null,
#                     "createTime": null,
#                     "anonymousState": 0,
#                     "domainId_txt": null,
#                     "endTime": null,
#                     "fup": null,
#                     "togetherData": null,
#                     "subject": "渣土运输车交通噪音扰民",
#                     "handleInfo": null,
#                     "groupId": null,
#                     "source_txt": null,
#                     "handleTogetherUnid": null,
#                     "source": "15",
#                     "togetherNum": 1,
#                     "complainList": null,
#                     "tid": "413436",
#                     "queryCode": 413436,
#                     "availableTime": 0,
#                     "timelyAnswered": 1,
#                     "limit": null,
#                     "commentsNum": 0,
#                     "markState": 1,
#                     "fid_txt": null,
#                     "isShowComment": 1,
#                     "nickName": "微信用户-155906114****",
#                     "queryDomainIds": null,
#                     "domainId": "10",
#                     "topicId": "0",
#                     "postCode": null,
#                     "lastupdate": 1563348423,
#                     "fids": "8",
#                     "keywordSet": null,
#                     "gids": "8,",
#                     "mtUnids": null,
#                     "isPush": null,
#                     "checkNum": 0,
#                     "queryKeywords": null,
#                     "answersList": null,
#                     "threadState": 1,
#                     "remark": null,
#                     "asids": "339369",
#                     "content": "晚上依旧渣土车高速轰鸣，大到以为是爆胎，完全没有人管一样，要求处理一下",
#                     "deleteInfo": null,
#                     "attachment": 0,
#                     "updateBy": null,
#                     "urgeNum": null,
#                     "complainDelayNum": null,
#                     "typeMap": null,
#                     "isHandOver": null,
#                     "mobile": null,
#                     "attachment_txt": null,
#                     "contentSet": null,
#                     "attachementsList": null,
#                     "handleTogetherHandleTime": "",
#                     "favoriteUserUnid": null,
#                     "createBy": null,
#                     "searchEndTimeTxt": null,
#                     "favNum": 0,
#                     "threadsToProcess": null,
#                     "searchValue": null
#                 }
#             }
#         ],
#         "code": 0,
#         "other": null
#     }
# }

# %% [markdown]
# # 批量爬取

# %%
import requests
import json
import csv
import time
import random
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from datetime import datetime
from tqdm import tqdm
import os
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

class RequestError(Exception):
    pass

def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=5,
        backoff_factor=2,
        status_forcelist=[500, 502, 503, 504, 429],
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    session.verify = False  # 禁用SSL验证
    return session

def get_search_results(session, keywords, pageNum, pageSize=100, max_retries=3):
    url = "https://api1.liuyan.cjn.cn/messageboard/api/essearch/querySearchMapByPage"
    headers = {
        'Accept': 'application/json, text/plain, */*',
        'Content-Type': 'application/x-www-form-urlencoded',
        'Origin': 'https://liuyan.cjn.cn',
        'Referer': 'https://liuyan.cjn.cn/',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0'
    }
    data = {
        'keywords': keywords,
        'pageSize': pageSize,
        'pageNum': pageNum
    }

    for attempt in range(max_retries):
        try:
            response = session.post(url, headers=headers, data=data, timeout=30)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            if attempt == max_retries - 1:
                raise RequestError(f"请求失败: {str(e)}")
            wait_time = (attempt + 1) * 15
            time.sleep(wait_time)

def convert_timestamp(timestamp):
    return datetime.fromtimestamp(timestamp).strftime("%Y-%m-%d %H:%M:%S")

def save_checkpoint(filename, last_page):
    with open(f"{filename}_checkpoint.txt", 'w') as f:
        f.write(str(last_page))

def load_checkpoint(filename):
    try:
        with open(f"{filename}_checkpoint.txt", 'r') as f:
            return int(f.read().strip())
    except FileNotFoundError:
        return 1

def main():
    keywords = "交通噪音"
    pageSize = 100
    filename = f"{keywords}.csv"
    session = create_session()
    
    try:
        # 加载断点
        start_page = load_checkpoint(filename)

        # 获取总数据量
        results = get_search_results(session, keywords, 1, pageSize)
        total = results['data']['total']
        total_pages = (total // pageSize) + (1 if total % pageSize else 0)
        
        # 计算剩余数据量
        remaining_records = total - ((start_page - 1) * pageSize)
        
        print(f"正在从第 {start_page} 页继续爬取，共 {total} 条数据")

        # 判断文件是否存在
        file_exists = os.path.exists(filename)
        
        with open(filename, 'a', newline='', encoding='utf-8-sig') as csvfile:
            fieldnames = ['fid', 'dateline', 'subject', 'typeId', 'userId', 'content']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            
            if not file_exists:
                writer.writeheader()

            # 使用全局计数器
            global_count = 0
            
            # 创建全局进度条
            with tqdm(total=remaining_records, desc="爬取进度", unit="条") as pbar:
                extracted_data = []
                for page in range(start_page, total_pages + 1):
                    try:
                        results = get_search_results(session, keywords, page)
                        data = results['data']['rows']

                        for item in data:
                            row_data = {
                                'fid': item['source']['fid'],
                                'dateline': convert_timestamp(item['source']['dateline']),
                                'subject': item['source']['subject'],
                                'typeId': item['source']['typeId'],
                                'userId': item['source']['userId'],
                                'content': item['source']['content']
                            }
                            extracted_data.append(row_data)
                            global_count += 1
                            pbar.update(1)

                            if len(extracted_data) >= 100:
                                writer.writerows(extracted_data)
                                csvfile.flush()
                                extracted_data = []

                        # 保存断点
                        save_checkpoint(filename, page + 1)
                        
                        # 随机延迟
                        time.sleep(random.uniform(7, 10))

                    except Exception as e:
                        if extracted_data:
                            writer.writerows(extracted_data)
                            csvfile.flush()
                        save_checkpoint(filename, page)
                        raise

                # 保存剩余数据
                if extracted_data:
                    writer.writerows(extracted_data)

        print(f"\n数据已保存到 {filename}")
        
        # 爬取完成后删除断点文件
        try:
            os.remove(f"{filename}_checkpoint.txt")
        except FileNotFoundError:
            pass

    except Exception as e:
        print(f"\n发生错误: {str(e)}")
        print("程序中断，已保存断点信息，下次运行将从中断处继续")

if __name__ == "__main__":
    main()
# Out:
# 正在从第 1 页继续爬取，共 144 条数据
# 爬取进度: 100%|██████████████████████████████████████████████████████████████████████| 144/144 [00:18<00:00,  7.65条/s]
# 数据已保存到 交通噪音.csv
